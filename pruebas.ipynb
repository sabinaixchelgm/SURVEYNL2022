# %%
import pandas as pd

# %%
df1=pd.read_csv("./EAV_2021.csv",low_memory=False)

# %%
df1.to_excel("output.xlsx", encoding='utf8')

# %%
df1.sort_values(by=['id'],inplace=True)
del df1['fac']
del df1['facint']
del df1['m06_loc']
del df1['m07_nom']
del df1['m09_mza']
del df1['m11_orde']
del df1['m01_orde']
del df1['m02_orde']
del df1['m03_orde']
del df1['m12_mun']
del df1['m14_juri']
del df1['m16_vivi']
del df1['m19_orde']

# %%
df_amm=df1[~(df1['m15_muni']==0)]
df_amm.set_index("id", inplace = True)
df_amm
# Out:
#       m04_mun   m05_nom m08_ageb  m10_pobt  m13_regi  m15_muni  m17_sexo  \
# id
# 1           6   Apodaca       51        16         1         6         1
# 2           6   Apodaca       51        80         1         6         0
# 3           6   Apodaca       70        30         1         6         1
# 4           6   Apodaca      102        89         1         6         0
# 5           6   Apodaca      117       143         1         6         1
# ...       ...       ...      ...       ...       ...       ...       ...
# 3872       49  Santiago      561         4         2        49         0
# 3873       49  Santiago      580        24         2        49         1
# 3874       49  Santiago      608       146         2        49         0
# 3875       49  Santiago      608       146         2        49         1
# 3876       49  Santiago      646        67         2        49         1
#
#      m18_sex  m20_muni  m21_orde  ...  cgoviajevuelta_camion  costotot_camion  \
# ...

# %%
del df_amm['m15_muni']
del df_amm['m20_muni']
del df_amm['m21_orde']
del df_amm['m22__ndi']
del df_amm['m23_orde']
del df_amm['m24_sour']
del df_amm['m25_orde']
del df_amm['m26_orde']
del df_amm['n01_encu']
del df_amm['n03_n_me']
del df_amm['n05_muni']
del df_amm['n07_dura']
del df_amm['n08_lati']
del df_amm['n09_long']

# %%
df_amm
# Out:
#       m04_mun   m05_nom m08_ageb  m10_pobt  m13_regi  m17_sexo m18_sex  \
# id
# 1           6   Apodaca       51        16         1         1   Mujer
# 2           6   Apodaca       51        80         1         0  Hombre
# 3           6   Apodaca       70        30         1         1   Mujer
# 4           6   Apodaca      102        89         1         0  Hombre
# 5           6   Apodaca      117       143         1         1   Mujer
# ...       ...       ...      ...       ...       ...       ...     ...
# 3872       49  Santiago      561         4         2         0  Hombre
# 3873       49  Santiago      580        24         2         1   Mujer
# 3874       49  Santiago      608       146         2         0  Hombre
# 3875       49  Santiago      608       146         2         1   Mujer
# 3876       49  Santiago      646        67         2         1   Mujer
#
#                 n02_call          n04_colo          n06_fech  ...  \
# ...

# %%
list(df_amm.columns)
# Out:
# ['m04_mun',
#  'm05_nom',
#  'm08_ageb',
#  'm10_pobt',
#  'm13_regi',
#  'm17_sexo',
#  'm18_sex',
#  'n02_call',
#  'n04_colo',
#  'n06_fech',
#  'cp1',
#  'cp1_n1',
#  'cp2_1',
#  'cp3_a1',
#  'cp3_m1',
#  'cp4_1',
#  'cp5_1',
#  'cp6_1_1',
#  'cp6_2_1',
#  'cp7_1',
#  'p76_1_1',
#  'p76_2_1',
#  'p77_1_1',
#  'p77_2_1',
#  'p77_3_1',
#  'p77_4_1',
#  'p78_1',
#  'cp8_1',
#  'cp9_1_1',
#  'cp9_2_1',
#  'cp9_3_1',
#  'cp9_4_1',
#  'cp1_n2',
#  'cp2_2',
#  'cp3_a2',
#  'cp3_m2',
#  'cp4_2',
#  'cp5_2',
#  'cp6_1_2',
#  'cp6_2_2',
#  'cp7_2',
#  'p76_1_2',
#  'p76_2_2',
#  'p77_1_2',
#  'p77_2_2',
#  'p77_3_2',
#  'p77_4_2',
#  'p78_2',
#  'cp8_2',
#  'cp9_1_2',
#  'cp9_2_2',
#  'cp9_3_2',
#  'cp9_4_2',
#  'cp1_n3',
#  'cp2_3',
#  'cp3_a3',
#  'cp3_m3',
#  'cp4_3',
#  'cp5_3',
#  'cp6_1_3',
#  'cp6_2_3',
#  'cp7_3',
#  'p76_1_3',
#  'p76_2_3',
#  'p77_1_3',
#  'p77_2_3',
#  'p77_3_3',
#  'p77_4_3',
#  'p78_3',
#  'cp8_3',
#  'cp9_1_3',
#  'cp9_2_3',
#  'cp9_3_3',
#  'cp9_4_3',
# ...

# %%
{
    'm04_mun':'clave_mun',
    'm05_nom':'mun_str',
    'm08_ageb':'ageb',
    'm10_pobt':'pobtotal_por_mza_ageb',
    'm13_regi':'region',
    'm17_sexo':'sexo_entrevistado_bin',
    'm18_sex':'sexo_entrevistado_str',
    'n02_call':'calle',
    'n04_colo':'colonia',
    'n06_fech':'fecha',
    'cp1':'personas_en_hogar',
    'cp1_n1':'nombre_entrevistado',
    
    
    ''
}
